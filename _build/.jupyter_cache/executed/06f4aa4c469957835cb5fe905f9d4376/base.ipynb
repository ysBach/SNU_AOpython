# %%
# %load_ext version_information
import time
now = time.strftime("%Y-%m-%d %H:%M:%S (%Z = GMT%z)")
print(f"This notebook was generated at {now} ")

vv = %version_information astropy, numpy, scipy, matplotlib, astroquery, photutils, version_information
for i, pkg in enumerate(vv.packages):
    print(f"{i} {pkg[0]:10s} {pkg[1]:s}")
# Out:
# This notebook was generated at 2023-04-27 13:34:17 (KST = GMT+0900)
# 0 Python     3.10.10 64bit [Clang 14.0.6 ]
# 1 IPython    8.7.0
# 2 OS         macOS 13.1 arm64 arm 64bit
# 3 astropy    5.2.2
# 4 numpy      1.23.2
# 5 scipy      1.10.1
# 6 matplotlib 3.7.1
# 7 astroquery 0.4.7.dev8438
# 8 photutils  1.6.1.dev103+gad22185f
# 9 version_information 1.0.4

# %%
# %matplotlib notebook
from IPython.core.interactiveshell import InteractiveShell
from IPython import get_ipython
# %config InlineBackend.figure_format = 'retina'
InteractiveShell.ast_node_interactivity = 'last_expr'
ipython = get_ipython()

from pathlib import Path

import numpy as np

from astropy import units as u
from astropy.nddata import CCDData
from astropy.coordinates import SkyCoord

from astroquery.gaia import Gaia
from astroquery.mast import Catalogs
Gaia.ROW_LIMIT = -1  # no limit

from matplotlib import pyplot as plt
from matplotlib import rcParams
plt.style.use('default')
rcParams.update({'font.size':12})

from photutils.aperture import (CircularAperture, CircularAnnulus, 
                                aperture_photometry, ApertureStats)
from photutils.detection import DAOStarFinder

import warnings
warnings.filterwarnings('ignore', category=UserWarning, append=True)

import _tool_visualization as vis

DATAPATH = Path('../../Tutorial_Data')
TMPDIR = Path('tmp')
TMPDIR.mkdir(exist_ok=True)

allfits = list(DATAPATH.glob("*p4179*.fits"))
allfits.sort()

ccd = CCDData.read(allfits[0])
# Out:
# WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / Telescope Coordinate System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]

# %%
print(ccd.wcs)

pix_scale = 0.4*u.arcsec

center_xy = np.array(ccd.shape)/2
center_radec = ccd.wcs.wcs_pix2world(*center_xy, 0)
center_coo = SkyCoord(*center_radec, unit='deg')

width, height = np.array(ccd.shape)*pix_scale

print("\nCoordinate of the center of the image:\n", center_coo)

fov_radius = np.sqrt((np.array(ccd.shape)**2).sum())/2 * pix_scale
# Out:
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN'  'DEC--TAN'
# CRVAL : 204.8640878996  -8.991494826739
# CRPIX : -4068.090526349  5085.76507007
# PC1_1 PC1_2  : -0.0001096993846665  -1.593373136163e-06
# PC2_1 PC2_2  : -2.91576786403e-07  0.0001095957848141
# CDELT : 1.0  1.0
# NAXIS : 999  999
#
# Coordinate of the center of the image:
#  <SkyCoord (ICRS): (ra, dec) in deg
#     (204.36178211, -9.49675272)>
# /Users/ysbach/miniforge3/lib/python3.10/site-packages/astropy/wcs/wcs.py:3064: RuntimeWarning: cdelt will be ignored since cd is present
#   description.append(s.format(*self.wcs.cdelt))

# %%
# =====
# If you want to use MAST, only DR2 is available as of 2023-04-26. 
# You can uncomment q_gaia line.
# Gaia DR2 needs `version=2`
# q_gaia = Catalogs.query_region(center_coo, radius=fov_radius, catalog="Gaia", version=2) 
# =====

# Set default table as DR3 and GAIA_SOURCE.
Gaia.MAIN_GAIA_TABLE = "gaiadr3.gaia_source"
q_gaia = Gaia.query_object_async(coordinate=center_coo, width=width, height=height)

# PS1 DR2 needs `data_release="dr2"`.
q_ps = Catalogs.query_region(center_coo, radius=fov_radius, catalog="Panstarrs", 
                             data_release="dr2", table="mean")
# Change some column names for convenience.
q_ps["raMean"].name = "ra"
q_ps["decMean"].name = "dec"
q_ps["gMeanPSFMag"].name = "g"
q_ps["rMeanPSFMag"].name = "r"

print("Number of results:",len(q_gaia))
print("Number of results:",len(q_ps))
# Out:
# INFO: Query finished. [astroquery.utils.tap.core]
# Number of results: 75
# Number of results: 5907

# %%
print("Number of columns in Gaia, PS1:", len(q_gaia.colnames), len(q_ps.colnames))
# Out:
# Number of columns in Gaia, PS1: 153 125

# %%
coef = np.array([-0.02704, 0.1425, -0.2156, 0.01426])
rmse = 0.03017
color = q_gaia["bp_rp"]

# Add useful columns
q_gaia["bp_snr"] = 1/q_gaia["phot_bp_mean_flux_over_error"]
q_gaia["rp_snr"] = 1/q_gaia["phot_rp_mean_flux_over_error"]
q_gaia["g_snr"] = 1/q_gaia["phot_g_mean_flux_over_error"]

# Calculate color error
q_gaia["dC"] = 2.5/np.log(10)*np.sqrt((q_gaia["rp_snr"])**2 + (q_gaia["bp_snr"])**2)

# Calculate V-mag and error
q_gaia["V"] = (
    q_gaia["phot_g_mean_mag"]
    + coef[0] + coef[1]*color + coef[2]*color**2 + coef[3]*color**3
)
q_gaia["dV"] = np.sqrt(
    2.5/np.log(10)*q_gaia["g_snr"]**2
    + (coef[1] + 2*coef[2]*color + 3*coef[3]*color**2)**2*q_gaia["dC"]**2
    + rmse**2
)

# Only select stars with good color
mask = (-0.5 < color) & (color < 5)
q1 = q_gaia["ra", "dec", "bp_rp", "g_snr", "bp_snr", "rp_snr", "dC", "V", "dV"][mask]

# Calculate x, y position
coo = SkyCoord(q1["ra"], q1["dec"], unit='deg')
q1["x"], q1["y"] = ccd.wcs.wcs_world2pix(coo.ra, coo.dec, 0)

# Remove stars outside the image
q1 = q1[(q1["x"] > 10) & (q1["x"] < ccd.shape[1]-10) 
        & (q1["y"] > 10) & (q1["y"] < ccd.shape[0]-10)]

# print
print(f"Total {len(q1)} stars")
q1.round(3)
q1
# Out:
# Total 65 stars
# <Table length=65>
#    ra     dec    bp_rp   g_snr   bp_snr  rp_snr    dC      V       dV      x       y
#   deg     deg     mag
# float64 float64 float32 float32 float32 float32 float32 float32 float32 float64 float64
# ------- ------- ------- ------- ------- ------- ------- ------- ------- ------- -------
# 204.352  -9.504   0.732   0.016   0.139   0.188   0.254  20.859   0.051 586.313 435.758
# 204.373  -9.505   2.855   0.002   0.033   0.004   0.036  16.681   0.041 399.077 428.649
# 204.373  -9.505   2.871   0.006   0.016    0.01    0.02  16.781   0.034 399.015 427.491
# 204.373  -9.505   2.748   0.005   0.245   0.087   0.282  19.131   0.205 403.101 420.853
#  204.35  -9.508   1.956   0.004    0.13   0.051   0.152  19.712   0.087 607.765 395.122
# 204.378  -9.502    0.28   0.003   0.035   0.058   0.073  19.432    0.03  355.88 450.611
#  204.34  -9.486    2.01   0.003   0.092   0.032   0.106  19.125   0.066 692.754 596.982
# 204.343  -9.514   2.116   0.005   0.116   0.037   0.132  19.665   0.082 669.384 345.025
# 204.341  -9.513    1.08     0.0   0.002   0.002   0.003   15.47    0.03 684.598 352.004
# 204.345  -9.518   1.801   0.006   0.135   0.061   0.161  20.172   0.085 650.856  304.49
# 204.334  -9.502   0.732   0.005   0.085   0.077   0.125  20.313   0.036 752.049  455.31
# 204.377  -9.523   1.174   0.002   0.013   0.009   0.017  17.866   0.031 367.571 259.337
#  204.35  -9.469   0.725   0.003    0.04   0.039   0.061  19.568   0.032 599.882 755.681
# 204.379  -9.471   1.173   0.012   0.206   0.138   0.269  20.741   0.088 338.946  728.53
# 204.375  -9.469    2.53   0.002   0.059    0.01   0.065  18.277   0.054 379.274 753.508
# 204.352  -9.467   1.924   0.001   0.019   0.008   0.023  17.426   0.032 582.302 772.492
# 204.376  -9.468   1.026   0.007   0.112   0.132   0.188  20.495   0.057 366.729 759.281
# 204.387  -9.517   0.638     0.0   0.003   0.003   0.004  15.986    0.03 273.809 314.073
#  204.33  -9.513   2.294   0.005   0.135   0.047   0.155  19.702   0.101 783.429 350.589
#     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...
# 204.384  -9.542   1.766   0.015   0.166   0.051   0.188  20.213   0.098  306.31  90.397
# 204.354  -9.447   2.059   0.001    0.04   0.012   0.045  17.944   0.039  562.63 949.677
# 204.354  -9.547   0.941   0.001   0.011   0.008   0.015  17.691    0.03 573.426  44.983
# 204.313  -9.517   1.127   0.005   0.103   0.066   0.133  20.153   0.049   938.2 315.155
# 204.335  -9.451   1.016   0.001    0.01    0.01   0.015  17.618    0.03 730.181 914.864
# 204.375  -9.445    1.64   0.001   0.033   0.006   0.036  17.561   0.034 374.606 964.896
# 204.308  -9.506   0.996     0.0   0.001   0.001   0.002  14.891    0.03 980.531 417.518
#  204.31  -9.479   0.783   0.001   0.005   0.006   0.008  16.631    0.03 959.438 663.959
# 204.399  -9.536   0.466   0.014   0.181   0.199   0.292  20.873   0.036 167.756  139.08
#  204.31  -9.476   0.966   0.002   0.044   0.029   0.057  19.063   0.033 962.303 689.623
# 204.392   -9.45   1.706   0.003   0.076   0.039   0.093  19.268   0.053 226.356 925.276
# 204.386  -9.446   0.317   0.012   0.102   0.156   0.202  20.858   0.033 280.684 962.428
# 204.402  -9.453   0.858   0.005   0.143   0.078   0.176   20.26   0.046 139.056 892.001
#  204.33  -9.547   1.386   0.002   0.008   0.004   0.009  16.915    0.03 789.271  46.365
# 204.326  -9.449   0.959   0.001   0.004   0.004   0.006  16.488    0.03 814.182 930.355
# 204.391  -9.549   2.686   0.002   0.098   0.014   0.107  18.153   0.082 243.065   27.85
# 204.401  -9.545   0.745   0.001   0.017   0.012   0.023  17.642    0.03 150.905  61.991
# 204.398   -9.55   0.947   0.002   0.045   0.038   0.064  19.208   0.034 176.525  15.585
# 204.321  -9.549   0.664   0.004   0.064   0.068   0.102  20.012   0.033 873.151  20.835
#  204.41  -9.543   1.536   0.002    0.04   0.019   0.048  18.844   0.036  68.817  76.787

# %%
# drop stars with unknown magnitudes
q_ps = q_ps.to_pandas().dropna(subset=["g", "r"])

# Calculate V and R
q_ps["V"] = 0.006 + 0.474*q_ps["g"] + 0.526*q_ps["r"]
q_ps["R"] = -0.138 - 0.131*q_ps["g"] + 1.131*q_ps["r"]
q_ps["dV"] = np.sqrt(
    0.474**2*q_ps["gMeanPSFMagErr"]**2 
    + 0.526**2*q_ps["rMeanPSFMagErr"]**2 + 0.012**2
)
q_ps["dR"] = np.sqrt(
    0.131**2*q_ps["gMeanPSFMagErr"]**2
    + 1.131**2*q_ps["rMeanPSFMagErr"]**2 + 0.015**2
)

# Select only important columns
q2 = q_ps[["ra", "dec", "g", "r", "V", "R", "dV", "dR"]].copy().reset_index(drop=True)

# Select only brighter than 22 mag
q2 = q2[(q2["V"] < 22) & (q2["R"] < 22)].copy().reset_index(drop=True)

# Calculate x, y position
coo = SkyCoord(q2["ra"], q2["dec"], unit='deg')
q2["x"], q2["y"] = ccd.wcs.wcs_world2pix(coo.ra, coo.dec, 0)

# Remove stars outside the image
q2 = q2[(q2["x"] > 10) & (q2["x"] < ccd.shape[1]-10) 
        & (q2["y"] > 10) & (q2["y"] < ccd.shape[0]-10)]

# print
print(f"Total {len(q2)} stars")
q2.round(3)
q2
# Out:
# Total 126 stars
#              ra       dec          g          r          V          R  \
# 0    204.369963 -9.542170  18.579300  17.738100  18.142829  17.489903
# 1    204.389764 -9.545102  21.836500  21.767401  21.806154  21.620349
# 2    204.391047 -9.548554  20.947399  19.787701  20.343398  19.497780
# 3    204.398498 -9.549908  19.685900  19.234800  19.454621  19.037706
# 4    204.401293 -9.544794  17.974100  17.651400  17.810360  17.471126
# ..          ...       ...        ...        ...        ...        ...
# 192  204.356024 -9.473706  21.466400  21.440001  21.458514  21.298542
# 193  204.362301 -9.474266  21.532801  20.370701  20.927536  20.080466
# 194  204.374899 -9.468714  20.582300  19.354200  19.942320  19.055319
# 195  204.376268 -9.468096  21.294100  20.548100  20.907704  20.312373
# 196  204.379406 -9.471473  21.567101  20.754900  21.145883  20.510502
#
#            dV        dR           x           y
# 0    0.013157  0.017456  431.255563   86.504457
# 1    0.087155  0.045529  254.184915   59.466713
# 2    0.027017  0.042565  243.074731   28.045018
# 3    0.013322  0.017627  176.493198   15.583189
# 4    0.012964  0.017497  150.902974   62.031846
# ..        ...       ...         ...         ...
# 192  0.030001  0.055501  548.583846  708.910974
# 193  0.122279  0.201271  492.411923  703.683137
# 194  0.020644  0.027026  378.970042  753.773854
# 195  0.023847  0.032114  366.650284  759.346963
# 196  0.033200  0.053949  338.906575  728.624061
#
# [126 rows x 10 columns]

# %%
aps1 = CircularAperture(np.array([q1["x"], q1["y"]]).T, r=12)
aps2 = CircularAperture(np.array([q2["x"], q2["y"]]).T, r=15)

fig, axs = plt.subplots(1, 1, figsize=(8, 5), sharex=False, sharey=False, gridspec_kw=None)

vis.norm_imshow(axs, ccd, zscale=True)
aps1.plot(color='r', lw=1, alpha=0.5, ax=axs)
aps2.plot(color='k', lw=1, alpha=0.5, ax=axs)

for c, l in zip("rk", ["Gaia", "PS1"]):
    axs.plot(np.nan, np.nan, f"{c}", label=l)
axs.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

plt.tight_layout()
plt.show();

# %%
ccd.header
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                  -32 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                  999
# NAXIS2  =                  999
# EXTEND  =                    T
# ORIGIN  = 'NOAO-IRAF FITS Image Kernel July 2003' / FITS file originator
# DATE    = '2018-05-15T05:11:58' / Date FITS file was generated
# IRAF-TLM= '2018-05-15T05:11:57' / Time of last modification
# OBJECT  = 'A00360-TO'          / Name of the object observed
# BUNIT   = 'adu     '           / units of physical values (LBT)
# DETECTOR= 'e2v CCD290-99'         / Detector name
# NAMPS   =                    8 / Number of amplifiers in the detector
# GAINDL                         / Pixel integration time, in sequencer clocks
# PIXITIME                       / Pixel integration time, in seconds
# CCDXBIN =                    1 / CCD X-axis Binning Factor
# CCDYBIN =                    1 / CCD Y-axis Binning Factor
# OVERSCNX=                   32 / Horizontal overscan pixels per amplifier
# OVERSCNY=                    0 / Vertical overscan pixels
# PRESCANX=                   27 / Horizontal prepixels per amplifier
# READOUT = 'ARLBRL  '           / Amplifiers used in readout
# PIXSCALE=                0.400 / Unbinned pixel scale [arcsec per pixel]
# PIXSIZE =                 10.0 / Unbinned pixel size [microns]
# OBSERVAT= 'SAAO    '              / Observatory Site
# TELESCOP= 'KMTNet 1.6m #2'        / Telescope Name
# LATITUDE= '-32:22:42'             / Site Latitude [deg N]
# LONGITUD= '339:11:22'             / Site Longitude [deg W]
# ELEVATIO=                 1800 / Site Elevation [meters]
# OBSERVER= 'PJK     '           / Observer(s)
# IMAGETYP= 'OBJECT  '           / Type of observation
# OBSTYPE = 'OBJECT  '           / Type of observation
# EXPTIME =                   60 / Exposure time [seconds]
# DARKTIME=                    0 / Cumulative Dark Time [seconds]
# TSHOPEN = '21:30:26.38'        / Master IC reports shutter open time
# TSHSHUT                        / Master IC reportsshutter close time
# DMAWAIT =                  500 / Master IC waits for slaves to set DMA
# NPHLINES=                   32 / Preheat lines prepare ADC electronics
# ICROLE  = 'MASTER  '           / ICs come in Masters and Slaves
# DATASRC = 'ADC     '           / CBBs do ADC, CTC, or SIM data sources
# CTCSOURC= 'FIRMWARE'           / CTC coefficients can come from FW or RAM
# CTCFILE = 'CTCDATA2.DAT'       / Source of CTC Coefficients
# HEMODE  = 'SCIENCE '           / CBBs have Science and Guide chip modes
# LEDFLASH=                    0 / Time to flash lab LEDs [seconds]
# FILENAME= '/PREPROC_STORAGE/d_SAAO_OBS/Y2018/20180413/PyMEF/kmts.20180413.0104&'
# CONTINUE  '49.fits&'
# CONTINUE  '' / MEF Filename
# UNIQNAME= '180413.000'         / Unique filename; if filename is invalid
# KBUILD  = 'KS2016-01-13:1370'  / K.IC software build
# MBUILD  = 'KS2016-01-13:1370'  / M.IC software build
# TBUILD  = 'KS2016-01-13:1370'  / T.IC software build
# NBUILD  = 'KS2016-01-13:1370'  / N.IC software build
# GBUILD  = '        '           / G.IC software build
# ICSBUILD= 'KX2016-03-23:1381'  / ICS software build
# INSTRUME= 'KMTS    '              / Instrument Name
# TCSLINK = 'Up      '           / TCS Communications Link Status
# TCSARC  = 'Enabled '           / TCS Link Auto Recovery Mode Status
# TCSQDATE= '2018-04-13T21:30:18.927' / UTC Date and Time of last TCS query
# TCSUDATE= '2018-04-13T21:30:18.208' / UTC Date and Time of last TCS update
# DATE-OBS= '2018-04-13T21:30:26' / ISO-8601 observation date matching MJD-OBS
# RADECSYS= 'ICRS    '              / Telescope Coordinate System
# RA      = '13:39:27.91'        / Telescope RA
# DEC     = '-08:59:54.5'        / Telescope DEC
# HA      = '-01:18:38'          / Hour Angle at start of obs
# ST      = '12:21:36'           / Local Sidereal Time at start of obs
# SECZ    = '1.15    '           / Secant of ZD (Airmass) at start of obs
# ALT     = '60.6    '           / Telesope Altitude (elevation) in degrees
# AZ      = '137.4   '           / Telescope Azimuth in degrees
# TCSDRIVE= 'Enabled '           / Telescope Drive Status
# TELMOVE = 'Idle    '           / Telescope Motion Status
# AUXLINK = 'Up      '           / AUX Control System Comm Link Status
# AUXARC  = 'Enabled '           / AUX Link Auto Recovery Mode Status
# AUXQDATE= '2018-04-13T21:30:18.031' / UTC Date and Time of last AUX query
# AUXUDATE= '2018-04-13T21:30:17.906' / UTC Date and Time of last AUX update
# FSSTAT  = 'STANDBY '           / Filter-Shutter Subsystem Status
# FILTOP  = 'STANDBY '           / Filter Operational Status
# FILNUM  = '3       '           / Filter selector position number
# SHUTOP  = 'STANDBY '           / Shutter Operational Status
# SHUTTER = 'CLOSED  '           / Shutter Position
# FASTAT  = 'STANDBY '           / Focus Acutator Subsystem Status
# FAFOCUS = '-5.710  '           / Focus Position Offset in millimeters
# FATILTNS= '-10.0   '           / Focus Tilt NS Offset Angle in arcsec
# FATILTEW= '-350.0  '           / Focus Tilt EW Offset Angle in arcsec
# FAPOSS  = '-5.661  '           / South Focus Actuator Position in millimeters
# FALIMS  = '0       '           / South Focus Actuator Limit Status
# FAPOSE  = '-7.217  '           / East Focus Actuator Position in millimeters
# FALIME  = '0       '           / East Focus Actuator Limit Status
# FAPOSW  = '-4.252  '           / West Focus Actuator Position in millimeters
# FALIMW  = '0       '           / West Focus Actuator Limit Status
# DSSTAT  = 'STANDBY '           / Dome Shutter Status
# DSUP    = 'OPEN    '           / Upper Dome Shutter Position
# DSLW    = 'OPEN    '           / Lower Dome Shutter Position
# DSSAF   = 'INACTIVE'           / Dome Shutter Safety Status
# DSAUTO  = 'DISABLED'           / Dome Shutter Autosync Status
# DSALT   = '87.1    '           / Dome Shutter Altitude in degrees
# DSTEL   = '60.6    '           / Dome Shutter Telescope Altitude in degrees
# MCSTAT  = 'STANDBY '           / Mirror Cover Status
# MCPOS   = '100     '           / Mirror Cover Position in percent
# CHSTAT  = 'NC      '           / Chiller Status
# CHOP                           / Chiller Cooling On or Off
# CHSET                          / Chiller Set Point Temperature in degrees C
# CHPROC                         / Chiller Protection Temperature in degrees C
# ENSTAT  = 'STANDBY '           / Environmental Control System Status
# ENFAN   = 'OFF     '           / Env System Fan On or Off
# ENS1    = '10.7    '           / Env Sensor 1 deg C or percent RH
# ENS2    = '11.4    '           / Env Sensor 2 deg C or percent RH
# ENS3    = '13.0    '           / Env Sensor 3 deg C or percent RH
# ENS4    = '60.3    '           / Env Sensor 4 deg C or percent RH
# ENS5    = '13.6    '           / Env Sensor 5 deg C or percent RH
# ENS6    = '13.3    '           / Env Sensor 6 deg C or percent RH
# ENS7    = '0.0     '           / Env Sensor 7 deg C or percent RH
# DEWPRES = 'N/A     '           / Dewar pressure
# CCDTEMP = '-109.6  '           / CCD Temperature
# PT30N1  = '-147.7  '           /
# PT30N2  = '-131.1  '           /
# CHARCOAL= '-197.5  '           /
# AIR_IN  = '+20.26  '           /
# AIR_OUT = '+23.44  '           /
# GLYC_IN = '+17.22  '           /
# GLYC_OUT= '+16.79  '           /
# RTD12
# DETSIZE = '[1:18892,1:19397]'  / KMNT Mosaic size in Pixels
# UT      = '2018-04-13T21:30:26.38' / Master IC reports shutter open time
# NUMFILES=                    4 / Number of Single-CCD FITS files
# KCCDFILE= 'KMTNk.20180413.010449.fits' / K CCD FITS File
# MCCDFILE= 'KMTNm.20180413.010449.fits' / M CCD FITS File
# TCCDFILE= 'KMTNt.20180413.010449.fits' / T CCD FITS File
# NCCDFILE= 'KMTNn.20180413.010449.fits' / N CCD FITS File
# COLGAP  =                  460 / Horizontal inter-CCD gap in pixels
# ROWGAP  =                  933 / Vertical inter-CCD gap in pixels
# MIDJD   =     2458222.39648151
# MIDHJD  =     2458222.40226015
# LJD     =             2458222.
# CCDMEAN =             87.59265
# REALDATA=                    T / Actual T01 stripe data
# CCDNAME = 'KMTNet CCD T'
# AMPNAME = 'T01     '
# AMPNAME2= 'im25    '
# GAIN    = '1.6     '
# RDNOISE = '6.6     '
# CCDSUM  = '1 1     '           / On-Chip Binning Factors
# CCDSEC  = '[1:9216,1:9232]'    / CCD Data Section
# AMPSEC  = '[1:9216,1:9232]'    / Amplifier Section
# DETSEC  = '[9677:18893,2:9233]' / Stripe Coords on Detector
# PRESEC  = '[1:27,1:9232]'      / Prescan Section
# IMFLIP  = 'None    '           / Raw Stripe Flip Applied
# FILTER  = 'V       '           / Filter Name in the beam
# PROJID  = 'NEO     '
# ATV1    =                    0 / CCD to Amplifier Transform
# ATV2    =                    0 / CCD to Amplifier Transform
# ATM1_1  =                    1 / CCD to Amplifier Transform
# ATM1_2  =                    0 / CCD to Amplifier Transform
# ATM2_1  =                    0 / CCD to Amplifier Transform
# ATM2_2  =                    1 / CCD to Amplifier Transform
# LTM1_1  =                    1 / CCD to Image Transform
# LTM2_2  =                    1 / CCD to Image Transform
# DTV1    =                 9676 / CCD to Detector Mosaic Transform
# DTV2    =                    1 / CCD to Detector Mosaic Transform
# DTM1_1  =                    1 / CCD to Detector Mosaic Transform
# DTM1_2  =                    0 / CCD to Detector Mosaic Transform
# DTM2_1  =                    0 / CCD to Detector Mosaic Transform
# DTM2_2  =                    1 / CCD to Detector Mosaic Transform
# WCSDIM  =                    2 / Coordinate System Dimensionality
# WAT0_001= 'system=image'       / Coordinate System
# WAT1_001= 'wtype=tan axtype=ra' / Coordinate Type
# WAT2_001= 'wtype=tan axtype=dec' / Coordinate Type
# TRIM    = 'Apr 13 23:06 Trim is [28:1179,1:9232]'
# OVERSCAN= 'Apr 13 23:06 Overscan is [1191:1200,1:9232], function=median'
# ZEROCOR = 'Apr 13 23:06 Zero is zero[T01]'
# FLATCOR = 'Apr 13 23:06 Flat is ../../MASTER/NEW/flatV.fits[T01], scale 25505.7'
# CCDPROC = 'Apr 13 23:06 CCD processing done'
# FIXPIX  = 'Apr 13 23:07 Bad pixel file is ../../BPM/SAAO_BPM.fits[25]'
# IMCMB001= 'xkmts.20180413.010449.fits[25]'
# IMCMB002= 'xkmts.20180413.010449.fits[26]'
# IMCMB003= 'xkmts.20180413.010449.fits[27]'
# IMCMB004= 'xkmts.20180413.010449.fits[28]'
# IMCMB005= 'xkmts.20180413.010449.fits[29]'
# IMCMB006= 'xkmts.20180413.010449.fits[30]'
# IMCMB007= 'xkmts.20180413.010449.fits[31]'
# IMCMB008= 'xkmts.20180413.010449.fits[32]'
# AMPMERGE= 'Apr 13 23:08 Merged 8 amps'
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# HISTORY   Astrometric solution by SCAMP version 2.0.1 (2016-09-12)
# COMMENT   (c) 2010-2013 IAP/CNRS/UPMC
# COMMENT
# EQUINOX =   2.000000000000E+03 / Mean equinox
# FGROUPNO=                    1 / SCAMP field group label
# ASTIRMS1=   0.000000000000E+00 / Astrom. dispersion RMS (intern., high S/N)
# ASTIRMS2=   0.000000000000E+00 / Astrom. dispersion RMS (intern., high S/N)
# ASTRRMS1=   6.639873813016E-05 / Astrom. dispersion RMS (ref., high S/N)
# ASTRRMS2=   5.333849878720E-05 / Astrom. dispersion RMS (ref., high S/N)
# ASTINST =                    1 / SCAMP astrometric instrument label
# FLXSCALE=   0.000000000000E+00 / SCAMP relative flux scale
# MAGZEROP=   0.000000000000E+00 / SCAMP zero-point
# PHOTIRMS=   0.000000000000E+00 / mag dispersion RMS (internal, high S/N)
# PHOTINST=                    1 / SCAMP photometric instrument label
# PHOTLINK=                    F / True if linked to a photometric field
# HISTORY   Astrometric solution by SCAMP version 2.0.4 (2016-07-05)
# COMMENT   (c) 2010-2013 IAP/CNRS/UPMC
# COMMENT
# LTV1    =               -3281.
# LTV2    =               -4150.
# HIERARCH TRIM_IMAGE = 'trimim  ' / Shortened name for ccdproc command
# TRIMIM  = 'ccd=<CCDData>'
# MJD-OBS =      58221.896134259 / [d] MJD of observation matching DATE-OBS
